# %% [markdown]
# Nama   : Risya Novita Ramadhani
# NIM    : 180441100004
# Kelas  : PBO "B"
#
# Catatan Kuliah Pemrograman Berbasis Objek
#
#     Materi  1 “Class vs Object"
#
#     Class merupakan rancangan yang mendefinisikan variable dan method-methode pada seluruh objek tertentu, sedangkan Objek juga merupakan benda nyata yang di buat berdasarkan rancangan yang di definisikan di dalam class. Fungsi dari class itu untuk menampung isi program yang akan dijalankan.
#     Di dalam sebuah class biasanya terdapat method atau fungsi. Method adalah kumpulan program yang mempunyai nama yang didalamnya berisi atribut (data yang terdapat dalam sebuah class).
# ![](./img/1.jpg)
# Nama class lebih baik diawali dengan huruf capital, dalam class menggunakan method bawaan python yang bernama init untuk menginisialisasi pembuatan objek dari kelas tersebut.
# Setiap method juga harus memiliki parameter self , yang artinya method tersebut dimiliki dan terdaftar ke class tersebut .
#
# Contoh program yang menggunakan class  :
# ![](./img/2.jpg)
# Contoh diatas program class kubus dengan method init dengan atribut sisi, method selanjutnya menampilkan sisi, luas permukaan dan volume dari kubus, setelah itu memanggil fungsi tersebut dengan memberi objek sisi pada variable class tersebut.
#
# Contoh yang kedua class pegawai :
# ![](./img/3.jpg)
# Class pegawai dengan atribut  nama, jabatan, dan gaji.
#
# Kesimpulan dari materi diatas class adalah template kode untuk membuat objek, objek memiliki variable anggota dan memiliki perilaku yang terkait dengannya.  Sedangkan objek dibuat menggunakan konstruktor dari kelas, objek ini kemudian akan disebut turunan dari kelas.
#
#     Materi  2 “ Inheritance”
# Inheritance atau biasa disebut dengan pewarisan adalah konsep pemrograman dimana sebuah class dapat menurunkan property dan method yang dimilikinya kepada class lain. Class yang akan diturunkan bisa disebut sebagai class induk (parent class) Sedangkan class yang menerima penurunan bisa disebut sebagai class anak (child class) atau juga sub class .
#
# ![](./img/6.jpg)
#
# Contoh program dengan class user sebagai induk class, dan class programmer sebagai sub class atau turunan dari class user. Disitu kita bisa langsung menggunakan property dari class user dan menampilkannya. Brian adalah sebuah instance atau variable yang bisa digunakan untuk mengakses kedua method dari kedua class tersebut.
# ![](./img/8.jpg)
#
#
#     Materi  3 “  Type of Inheritance”
#
# Jenis-jenis inheritance ada 4 :
# ![](./img/12%202.jpg)
#
#     1.Default (properti, properti dan metode)
#     2.Overriding (property/method, property dan method)
#     -kelas anak dapat mengatur nilai properti / metode pada kelas induk
#     3.Super ( properti )
#     Fungsi super () paling umum digunakan dalam metode __init __ () karena di situlah kita kemungkinan besar perlu menambahkan beberapa keunikan ke kelas anak dan kemudian menyelesaikan inisialisasi dari orangtua.
# Contoh program mengenai type default, overriding, dan super :
# ![](./img/13.jpg)
# ![](./img/14.jpg)
#     4.Multiple
#     Multile inheritance adalah ketika sebuah kelas dapat mewarisi atribut dan metode lebih dari satu kelas induk.
# Contoh program dari type multiple inheritance :
# ![](./img/15.jpg)
#
#
#     Materi  4 “Polymorphisme "
#
# Polymorphisme merupakan kemampuan suatu method untuk bekerja dengan lebih dari satu tipe argument. Polymorphisme juga dapat memiliki berbagai bentuk, sebagai object dari class sendiri  atau object dari superclassnya.
# Ada 2 operator :
#     -Operator overloading : penggunaan satu nama untuk beberapa method yang berbeda.
#     -Operator overriding   : terjadi ketika deklarasi method subclass dengan nama dan parameter yang sama dengan method dari superclassnya.
#     •Polymorphism with a Function
# Yakni membuat fungsi yang dapat mengambil objek apapun.
# Contoh programmnya :
# ![](./img/19.jpg)
#
# Masing-masing fungsi dari method ini berbeda untuk setiap class.
#
#     Polymorphism with Class Methods
# Method yang dilakukan dengan cara tanpa mengetahui apa type class dari masing-masing objek tersebut.
# Contoh programnya :
# ![](./img/20.jpg)
#
#
#     Abstract class adalah sebuah class yang tidak bisa di instansiasi(tidak bisa dibuat menjadi objek dan berperan sebagai kerangka dasar bagi class turunannya.
#
# Contoh  programmnya :
#
# Abstract class yang disebut Document, class ini tidak memiliki implementasi apapun tetapi mendefinisikan struktur (dalam bentuk fungsi) yang harus dimiliki semua bentuk. Contohnya jika kita mendefinisikan fungsi show() maka class pdf dan juga class word juga harus memiliki fungsi show()
# ![](./img/22.jpg)
# Materi  5 “ Encapsulation "
#
#      Encapsulation merupakan pembungkus class dan menjaga apa saja yang ada didalam class tersebut, baik method ataupun
# atribut, agar tidak dapat diakses oleh class lainnya. Untuk menjaga hal tersebut dalam encapsulation dikenal dengan nama hak akses modifier yang terdiri dari private dan public method.
#
# ![](./img/download.jpg)
# Untuk perbedaannya public methods sendiri dapat diakses dari mana saja, artinya method atau atribut yang ada di class A dapat diakses oleh siapapun baik itu class A, class B, dan seterusnya.
# Sedangkan private methods hanya dapat diakses kelas mereka sendiri dan biasanya dimulai dengan 2 garis bawah, artinya apa saja yang ada didalam class A baik itu method
# ataupun atribut hanya bisa diakses oleh class Asaja, class lain tidak bisa mengaksesnya
#
# ![](./img/image.png)
#
#
# Contoh program yang pertama :
# ![](./img/1.jpg)
# Contoh program yang kedua:
# ![](./img/2.jpg)
#
# Materi 6 " Operator dan Method Overloading "
#
#     Operator Overloading adalah operator yang digunakan sebagai pengganti fungsi inputan, output ataupun bisa fungsi yang lainnya. Overloading sendiri merupakan pembuatan fungsi-fungsi dengan nama sama tetapi jumlah parameter dari fungsi-fungsi tersebut berbeda. Fungsi operator  berperan sebagai anggota (member function ) dari kelas.
#     Operator Overloading dapat mendefinisikan 2 product method, tapi yang bisa digunakan hanya method yang kedua.
# Karena python tidak mendukung method overloading maka kita dapat mendefinisikan banyak method degan nama yang sama dan argumen yang berbeda tetapi kita hanya dapat menggunakan method yang didefinisikan terbaru.
# Contoh programnya :
# ![](./img/def%202.png)
# ![](./img/def.png)
